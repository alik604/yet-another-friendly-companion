# %% [markdown]
# # Deep Deterministic Policy Gradient (DDPG)
# > Alik604
#
# is a model-free off-policy algorithm for learning continous actions. It combines ideas from DPG (Deterministic Policy Gradient) and DQN (Deep Q-Network). It uses Experience Replay and slow-learning target networks from DQN, and it is based on DPG, which can operate over continuous action spaces.
#
# ### Source
# [code](https://github.com/philtabor/Youtube-Code-Repository/tree/master/ReinforcementLearning/PolicyGradient/DDPG/pytorch/lunar-lander)
#
# ## Results
#
# It didnt work for me... :'(
#
# trained with 0 changes, yes all 1000 epochs

# %%
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

import os
import gym
import pickle
import matplotlib.pyplot as plt

# %%
class OUActionNoise(object):
    def __init__(self, mu, sigma=0.15, theta=.2, dt=1e-2, x0=None):
        self.theta = theta
        self.mu = mu
        self.sigma = sigma
        self.dt = dt
        self.x0 = x0
        self.reset()

    def __call__(self):
        x = self.x_prev + self.theta * (self.mu - self.x_prev) * self.dt + \
            self.sigma * np.sqrt(self.dt) * np.random.normal(size=self.mu.shape)
        self.x_prev = x
        return x

    def reset(self):
        self.x_prev = self.x0 if self.x0 is not None else np.zeros_like(self.mu)

    def __repr__(self):
        return 'OrnsteinUhlenbeckActionNoise(mu={}, sigma={})'.format(self.mu, self.sigma)

class ReplayBuffer(object):
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, *input_shape))
        self.new_state_memory = np.zeros((self.mem_size, *input_shape))
        self.action_memory = np.zeros((self.mem_size, n_actions))
        self.reward_memory = np.zeros(self.mem_size)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.float32)

    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.terminal_memory[index] = 1 - done
        self.mem_cntr += 1

    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)

        batch = np.random.choice(max_mem, batch_size)

        states = self.state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        states_ = self.new_state_memory[batch]
        terminal = self.terminal_memory[batch]

        return states, actions, rewards, states_, terminal

# %%
class CriticNetwork(nn.Module):
    def __init__(self, beta, input_dims, fc1_dims, fc2_dims, n_actions, name,
                 chkpt_dir):
        super(CriticNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.checkpoint_file = os.path.join(chkpt_dir,name+'_ddpg')
        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        f1 = 1./np.sqrt(self.fc1.weight.data.size()[0])
        T.nn.init.uniform_(self.fc1.weight.data, -f1, f1)
        T.nn.init.uniform_(self.fc1.bias.data, -f1, f1)
        #self.fc1.weight.data.uniform_(-f1, f1)
        #self.fc1.bias.data.uniform_(-f1, f1)
        self.bn1 = nn.LayerNorm(self.fc1_dims)

        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        f2 = 1./np.sqrt(self.fc2.weight.data.size()[0])
        #f2 = 0.002
        T.nn.init.uniform_(self.fc2.weight.data, -f2, f2)
        T.nn.init.uniform_(self.fc2.bias.data, -f2, f2)
        #self.fc2.weight.data.uniform_(-f2, f2)
        #self.fc2.bias.data.uniform_(-f2, f2)
        self.bn2 = nn.LayerNorm(self.fc2_dims)

        self.action_value = nn.Linear(self.n_actions, self.fc2_dims)
        f3 = 0.003
        self.q = nn.Linear(self.fc2_dims, 1)
        T.nn.init.uniform_(self.q.weight.data, -f3, f3)
        T.nn.init.uniform_(self.q.bias.data, -f3, f3)
        #self.q.weight.data.uniform_(-f3, f3)
        #self.q.bias.data.uniform_(-f3, f3)

        self.optimizer = optim.Adam(self.parameters(), lr=beta)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cuda:1')

        self.to(self.device)

    def forward(self, state, action):
        state_value = self.fc1(state)
        state_value = self.bn1(state_value)
        state_value = F.relu(state_value)
        state_value = self.fc2(state_value)
        state_value = self.bn2(state_value)

        action_value = F.relu(self.action_value(action))
        state_action_value = F.relu(T.add(state_value, action_value))
        state_action_value = self.q(state_action_value)

        return state_action_value

    def save_checkpoint(self):
        print('... saving checkpoint ...')
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        print('... loading checkpoint ...')
        self.load_state_dict(T.load(self.checkpoint_file))

class ActorNetwork(nn.Module):
    def __init__(self, alpha, input_dims, fc1_dims, fc2_dims, n_actions, name,
                 chkpt_dir):
        super(ActorNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.checkpoint_file = os.path.join(chkpt_dir,name+'_ddpg')
        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        f1 = 1./np.sqrt(self.fc1.weight.data.size()[0])
        T.nn.init.uniform_(self.fc1.weight.data, -f1, f1)
        T.nn.init.uniform_(self.fc1.bias.data, -f1, f1)
        #self.fc1.weight.data.uniform_(-f1, f1)
        #self.fc1.bias.data.uniform_(-f1, f1)
        self.bn1 = nn.LayerNorm(self.fc1_dims)

        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        #f2 = 0.002
        f2 = 1./np.sqrt(self.fc2.weight.data.size()[0])
        T.nn.init.uniform_(self.fc2.weight.data, -f2, f2)
        T.nn.init.uniform_(self.fc2.bias.data, -f2, f2)
        #self.fc2.weight.data.uniform_(-f2, f2)
        #self.fc2.bias.data.uniform_(-f2, f2)
        self.bn2 = nn.LayerNorm(self.fc2_dims)

        #f3 = 0.004
        f3 = 0.003
        self.mu = nn.Linear(self.fc2_dims, self.n_actions)
        T.nn.init.uniform_(self.mu.weight.data, -f3, f3)
        T.nn.init.uniform_(self.mu.bias.data, -f3, f3)
        #self.mu.weight.data.uniform_(-f3, f3)
        #self.mu.bias.data.uniform_(-f3, f3)

        self.optimizer = optim.Adam(self.parameters(), lr=alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cuda:1')

        self.to(self.device)

    def forward(self, state):
        x = self.fc1(state)
        x = self.bn1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = T.tanh(self.mu(x))

        return x

    def save_checkpoint(self):
        print('... saving checkpoint ...')
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        print('... loading checkpoint ...')
        self.load_state_dict(T.load(self.checkpoint_file))

# %%
class Agent(object):
    def __init__(self, alpha, beta, input_dims, tau, env, gamma=0.99,
                 n_actions=2, max_size=1000000, layer1_size=400,
                 layer2_size=300, batch_size=64):
        self.gamma = gamma
        self.tau = tau
        self.memory = ReplayBuffer(max_size, input_dims, n_actions)
        self.batch_size = batch_size

        chkpt_dir = r'./save'

        self.actor = ActorNetwork(alpha, input_dims, layer1_size,
                                  layer2_size, n_actions=n_actions,
                                  name='Actor',chkpt_dir=chkpt_dir)
        self.critic = CriticNetwork(beta, input_dims, layer1_size,
                                    layer2_size, n_actions=n_actions,
                                    name='Critic',chkpt_dir=chkpt_dir)

        self.target_actor = ActorNetwork(alpha, input_dims, layer1_size,
                                         layer2_size, n_actions=n_actions,
                                         name='TargetActor',chkpt_dir=chkpt_dir)
        self.target_critic = CriticNetwork(beta, input_dims, layer1_size,
                                           layer2_size, n_actions=n_actions,
                                           name='TargetCritic',chkpt_dir=chkpt_dir)

        self.noise = OUActionNoise(mu=np.zeros(n_actions))

        self.update_network_parameters(tau=1)

    def choose_action(self, observation):
        self.actor.eval()
        observation = T.tensor(observation, dtype=T.float).to(self.actor.device)
        mu = self.actor.forward(observation).to(self.actor.device)
        mu_prime = mu + T.tensor(self.noise(),
                                 dtype=T.float).to(self.actor.device)
        self.actor.train()
        return mu_prime.cpu().detach().numpy()


    def remember(self, state, action, reward, new_state, done):
        self.memory.store_transition(state, action, reward, new_state, done)

    def learn(self):
        if self.memory.mem_cntr < self.batch_size:
            return
        state, action, reward, new_state, done = \
                                      self.memory.sample_buffer(self.batch_size)

        reward = T.tensor(reward, dtype=T.float).to(self.critic.device)
        done = T.tensor(done).to(self.critic.device)
        new_state = T.tensor(new_state, dtype=T.float).to(self.critic.device)
        action = T.tensor(action, dtype=T.float).to(self.critic.device)
        state = T.tensor(state, dtype=T.float).to(self.critic.device)

        self.target_actor.eval()
        self.target_critic.eval()
        self.critic.eval()
        target_actions = self.target_actor.forward(new_state)
        critic_value_ = self.target_critic.forward(new_state, target_actions)
        critic_value = self.critic.forward(state, action)

        target = []
        for j in range(self.batch_size):
            target.append(reward[j] + self.gamma*critic_value_[j]*done[j])
        target = T.tensor(target).to(self.critic.device)
        target = target.view(self.batch_size, 1)

        self.critic.train()
        self.critic.optimizer.zero_grad()
        critic_loss = F.mse_loss(target, critic_value)
        critic_loss.backward()
        self.critic.optimizer.step()

        self.critic.eval()
        self.actor.optimizer.zero_grad()
        mu = self.actor.forward(state)
        self.actor.train()
        actor_loss = -self.critic.forward(state, mu)
        actor_loss = T.mean(actor_loss)
        actor_loss.backward()
        self.actor.optimizer.step()

        self.update_network_parameters()

    def update_network_parameters(self, tau=None):
        if tau is None:
            tau = self.tau

        actor_params = self.actor.named_parameters()
        critic_params = self.critic.named_parameters()
        target_actor_params = self.target_actor.named_parameters()
        target_critic_params = self.target_critic.named_parameters()

        critic_state_dict = dict(critic_params)
        actor_state_dict = dict(actor_params)
        target_critic_dict = dict(target_critic_params)
        target_actor_dict = dict(target_actor_params)

        for name in critic_state_dict:
            critic_state_dict[name] = tau*critic_state_dict[name].clone() + \
                                      (1-tau)*target_critic_dict[name].clone()

        self.target_critic.load_state_dict(critic_state_dict)

        for name in actor_state_dict:
            actor_state_dict[name] = tau*actor_state_dict[name].clone() + \
                                      (1-tau)*target_actor_dict[name].clone()
        self.target_actor.load_state_dict(actor_state_dict)

    def save_models(self):
        self.actor.save_checkpoint()
        self.target_actor.save_checkpoint()
        self.critic.save_checkpoint()
        self.target_critic.save_checkpoint()

    def load_models(self):
        self.actor.load_checkpoint()
        self.target_actor.load_checkpoint()
        self.critic.load_checkpoint()
        self.target_critic.load_checkpoint()

    def check_actor_params(self):
        current_actor_params = self.actor.named_parameters()
        current_actor_dict = dict(current_actor_params)
        original_actor_dict = dict(self.original_actor.named_parameters())
        original_critic_dict = dict(self.original_critic.named_parameters())
        current_critic_params = self.critic.named_parameters()
        current_critic_dict = dict(current_critic_params)

        print('Checking Actor parameters')
        for param in current_actor_dict:
            print(param, T.equal(original_actor_dict[param], current_actor_dict[param]))

        print('Checking critic parameters')
        for param in current_critic_dict:
            print(param, T.equal(original_critic_dict[param], current_critic_dict[param]))
        # input()

# %%
def plotLearning(scores, filename, x=None, window=5):   
    N = len(scores)
    running_avg = np.empty(N)
    for t in range(N):
	    running_avg[t] = np.mean(scores[max(0, t-window):(t+1)])
    if x is None:
        x = [i for i in range(N)]
    plt.ylabel('Score')       
    plt.xlabel('Game')                     
    plt.plot(x, running_avg)
    plt.savefig(filename)

# %%
env = gym.make('LunarLanderContinuous-v2')
agent = Agent(alpha=0.000025, beta=0.00025, input_dims=[8], tau=0.001, env=env,
              batch_size=64,  layer1_size=400, layer2_size=300, n_actions=2)

np.random.seed(0)
score_history = []

# %%
# agent.alpha = .00025
# agent.beta  = .0025
# agent.load_models()

for i in range(300):
    obs = env.reset()
    done = False
    score = 0
    while not done:
        act = agent.choose_action(obs)
        new_state, reward, done, info = env.step(act)
        agent.remember(obs, act, reward, new_state, int(done))
        agent.learn()
        score += reward
        obs = new_state
    score_history.append(score)

    # if i % 25 == 0:
    #    agent.save_models()

    print('episode ', i, 'score %.2f' % score, 'trailing 50 games avg %.3f' % np.mean(score_history[-50:]))
agent.save_models()
filename = 'LunarLander-alpha000025-beta00025-400-300.png'
plotLearning(score_history, filename, window=25)
# Out:
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  0 score -163.02 trailing 50 games avg -163.021
# episode  1 score -25.04 trailing 50 games avg -94.029
# episode  2 score -133.05 trailing 50 games avg -107.037
# episode  3 score -181.31 trailing 50 games avg -125.606
# episode  4 score -142.11 trailing 50 games avg -128.906
# episode  5 score -204.22 trailing 50 games avg -141.458
# episode  6 score 1.00 trailing 50 games avg -121.107
# episode  7 score -128.13 trailing 50 games avg -121.985
# episode  8 score -356.70 trailing 50 games avg -148.064
# episode  9 score -540.84 trailing 50 games avg -187.341
# episode  10 score -559.52 trailing 50 games avg -221.176
# episode  11 score -291.05 trailing 50 games avg -226.999
# episode  12 score -350.88 trailing 50 games avg -236.528
# episode  13 score -299.18 trailing 50 games avg -241.003
# episode  14 score -140.81 trailing 50 games avg -234.323
# episode  15 score -289.46 trailing 50 games avg -237.770
# episode  16 score -146.00 trailing 50 games avg -232.371
# episode  17 score -129.15 trailing 50 games avg -226.637
# episode  18 score -249.30 trailing 50 games avg -227.829
# episode  19 score -316.52 trailing 50 games avg -232.264
# episode  20 score -424.82 trailing 50 games avg -241.433
# episode  21 score -169.30 trailing 50 games avg -238.154
# episode  22 score -155.24 trailing 50 games avg -234.549
# episode  23 score -140.08 trailing 50 games avg -230.613
# episode  24 score -159.57 trailing 50 games avg -227.771
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  25 score -6.81 trailing 50 games avg -219.273
# episode  26 score -6.86 trailing 50 games avg -211.406
# episode  27 score -123.77 trailing 50 games avg -208.276
# episode  28 score -117.40 trailing 50 games avg -205.142
# episode  29 score -96.51 trailing 50 games avg -201.521
# episode  30 score -120.91 trailing 50 games avg -198.920
# episode  31 score -96.55 trailing 50 games avg -195.722
# episode  32 score -161.41 trailing 50 games avg -194.682
# episode  33 score -91.13 trailing 50 games avg -191.636
# episode  34 score 305.80 trailing 50 games avg -177.424
# episode  35 score -113.83 trailing 50 games avg -175.657
# episode  36 score -146.54 trailing 50 games avg -174.870
# episode  37 score -130.38 trailing 50 games avg -173.700
# episode  38 score -115.18 trailing 50 games avg -172.199
# episode  39 score -163.88 trailing 50 games avg -171.991
# episode  40 score -105.29 trailing 50 games avg -170.364
# episode  41 score -84.96 trailing 50 games avg -168.331
# episode  42 score -149.12 trailing 50 games avg -167.884
# episode  43 score -370.46 trailing 50 games avg -172.488
# episode  44 score -1052.57 trailing 50 games avg -192.045
# episode  45 score -645.86 trailing 50 games avg -201.911
# episode  46 score -412.35 trailing 50 games avg -206.388
# episode  47 score -76.64 trailing 50 games avg -203.685
# episode  48 score -281.83 trailing 50 games avg -205.280
# episode  49 score -210.55 trailing 50 games avg -205.385
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  50 score -87.58 trailing 50 games avg -203.876
# episode  51 score -118.19 trailing 50 games avg -205.739
# episode  52 score -305.55 trailing 50 games avg -209.189
# episode  53 score -267.52 trailing 50 games avg -210.913
# episode  54 score -442.11 trailing 50 games avg -216.913
# episode  55 score -390.22 trailing 50 games avg -220.633
# episode  56 score -224.85 trailing 50 games avg -225.151
# episode  57 score -110.06 trailing 50 games avg -224.789
# episode  58 score 48.08 trailing 50 games avg -216.694
# episode  59 score -107.44 trailing 50 games avg -208.026
# episode  60 score -236.94 trailing 50 games avg -201.574
# episode  61 score -334.36 trailing 50 games avg -202.440
# episode  62 score -121.63 trailing 50 games avg -197.855
# episode  63 score -156.15 trailing 50 games avg -194.995
# episode  64 score -302.11 trailing 50 games avg -198.221
# episode  65 score -425.31 trailing 50 games avg -200.938
# episode  66 score -98.26 trailing 50 games avg -199.983
# episode  67 score -344.52 trailing 50 games avg -204.290
# episode  68 score -483.76 trailing 50 games avg -208.980
# episode  69 score -462.34 trailing 50 games avg -211.896
# episode  70 score -574.10 trailing 50 games avg -214.882
# episode  71 score -593.31 trailing 50 games avg -223.362
# episode  72 score -473.82 trailing 50 games avg -229.734
# episode  73 score -488.07 trailing 50 games avg -236.693
# episode  74 score -465.22 trailing 50 games avg -242.807
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  75 score -282.39 trailing 50 games avg -248.318
# episode  76 score -230.69 trailing 50 games avg -252.795
# episode  77 score -63.61 trailing 50 games avg -251.591
# episode  78 score -322.00 trailing 50 games avg -255.684
# episode  79 score -181.34 trailing 50 games avg -257.380
# episode  80 score -511.87 trailing 50 games avg -265.200
# episode  81 score -364.24 trailing 50 games avg -270.553
# episode  82 score -421.09 trailing 50 games avg -275.747
# episode  83 score -402.29 trailing 50 games avg -281.970
# episode  84 score -362.74 trailing 50 games avg -295.341
# episode  85 score -76.46 trailing 50 games avg -294.593
# episode  86 score -288.27 trailing 50 games avg -297.428
# episode  87 score -103.53 trailing 50 games avg -296.891
# episode  88 score -312.73 trailing 50 games avg -300.842
# episode  89 score -189.00 trailing 50 games avg -301.344
# episode  90 score -119.24 trailing 50 games avg -301.623
# episode  91 score -153.20 trailing 50 games avg -302.988
# episode  92 score 43.79 trailing 50 games avg -299.130
# episode  93 score -392.00 trailing 50 games avg -299.561
# episode  94 score -328.08 trailing 50 games avg -285.071
# episode  95 score -12.14 trailing 50 games avg -272.397
# episode  96 score -346.16 trailing 50 games avg -271.073
# episode  97 score -168.35 trailing 50 games avg -272.907
# episode  98 score -115.75 trailing 50 games avg -269.586
# episode  99 score -158.28 trailing 50 games avg -268.540
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  100 score -5.84 trailing 50 games avg -266.906
# episode  101 score -132.45 trailing 50 games avg -267.191
# episode  102 score -239.94 trailing 50 games avg -265.879
# episode  103 score -214.63 trailing 50 games avg -264.821
# episode  104 score -213.66 trailing 50 games avg -260.252
# episode  105 score -60.38 trailing 50 games avg -253.655
# episode  106 score -108.77 trailing 50 games avg -251.333
# episode  107 score -179.98 trailing 50 games avg -252.732
# episode  108 score -86.30 trailing 50 games avg -255.419
# episode  109 score -154.61 trailing 50 games avg -256.363
# episode  110 score -314.64 trailing 50 games avg -257.917
# episode  111 score -84.30 trailing 50 games avg -252.916
# episode  112 score -90.12 trailing 50 games avg -252.285
# episode  113 score -169.02 trailing 50 games avg -252.543
# episode  114 score -260.91 trailing 50 games avg -251.719
# episode  115 score -144.77 trailing 50 games avg -246.108
# episode  116 score -142.83 trailing 50 games avg -246.999
# episode  117 score -154.60 trailing 50 games avg -243.201
# episode  118 score -128.73 trailing 50 games avg -236.100
# episode  119 score -313.74 trailing 50 games avg -233.128
# episode  120 score -444.34 trailing 50 games avg -230.533
# episode  121 score 22.89 trailing 50 games avg -218.209
# episode  122 score -102.57 trailing 50 games avg -210.784
# episode  123 score -44.90 trailing 50 games avg -201.920
# episode  124 score -38.17 trailing 50 games avg -193.379
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  125 score -130.24 trailing 50 games avg -190.336
# episode  126 score -42.04 trailing 50 games avg -186.563
# episode  127 score -124.67 trailing 50 games avg -187.784
# episode  128 score -156.45 trailing 50 games avg -184.473
# episode  129 score -180.19 trailing 50 games avg -184.450
# episode  130 score -121.47 trailing 50 games avg -176.642
# episode  131 score -102.11 trailing 50 games avg -171.400
# episode  132 score -50.53 trailing 50 games avg -163.988
# episode  133 score -362.67 trailing 50 games avg -163.196
# episode  134 score -66.69 trailing 50 games avg -157.275
# episode  135 score -142.86 trailing 50 games avg -158.603
# episode  136 score -135.90 trailing 50 games avg -155.556
# episode  137 score -101.24 trailing 50 games avg -155.510
# episode  138 score -137.84 trailing 50 games avg -152.012
# episode  139 score -41.11 trailing 50 games avg -149.054
# episode  140 score -82.96 trailing 50 games avg -148.329
# episode  141 score -51.95 trailing 50 games avg -146.304
# episode  142 score -89.34 trailing 50 games avg -148.966
# episode  143 score -148.66 trailing 50 games avg -144.099
# episode  144 score -57.48 trailing 50 games avg -138.687
# episode  145 score -165.69 trailing 50 games avg -141.758
# episode  146 score -65.27 trailing 50 games avg -136.140
# episode  147 score -153.26 trailing 50 games avg -135.839
# episode  148 score -311.27 trailing 50 games avg -139.749
# episode  149 score -138.43 trailing 50 games avg -139.352
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  150 score -165.83 trailing 50 games avg -142.552
# episode  151 score -34.03 trailing 50 games avg -140.584
# episode  152 score -101.89 trailing 50 games avg -137.823
# episode  153 score -153.49 trailing 50 games avg -136.600
# episode  154 score -115.14 trailing 50 games avg -134.630
# episode  155 score 163.83 trailing 50 games avg -130.145
# episode  156 score -204.72 trailing 50 games avg -132.064
# episode  157 score -65.19 trailing 50 games avg -129.768
# episode  158 score -244.97 trailing 50 games avg -132.942
# episode  159 score -271.81 trailing 50 games avg -135.286
# episode  160 score -164.17 trailing 50 games avg -132.277
# episode  161 score -118.73 trailing 50 games avg -132.965
# episode  162 score -205.31 trailing 50 games avg -135.269
# episode  163 score 10.65 trailing 50 games avg -131.676
# episode  164 score -394.45 trailing 50 games avg -134.346
# episode  165 score -87.43 trailing 50 games avg -133.200
# episode  166 score -281.98 trailing 50 games avg -135.983
# episode  167 score -76.14 trailing 50 games avg -134.414
# episode  168 score -52.92 trailing 50 games avg -132.897
# episode  169 score 234.59 trailing 50 games avg -121.931
# episode  170 score -228.60 trailing 50 games avg -117.616
# episode  171 score -67.31 trailing 50 games avg -119.420
# episode  172 score -158.40 trailing 50 games avg -120.537
# episode  173 score -67.76 trailing 50 games avg -120.994
# episode  174 score -100.18 trailing 50 games avg -122.234
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  175 score -103.64 trailing 50 games avg -121.702
# episode  176 score -163.57 trailing 50 games avg -124.133
# episode  177 score -84.81 trailing 50 games avg -123.336
# episode  178 score -169.96 trailing 50 games avg -123.606
# episode  179 score -16.29 trailing 50 games avg -120.328
# episode  180 score -119.49 trailing 50 games avg -120.289
# episode  181 score -136.90 trailing 50 games avg -120.984
# episode  182 score -344.80 trailing 50 games avg -126.870
# episode  183 score -196.40 trailing 50 games avg -123.544
# episode  184 score -329.22 trailing 50 games avg -128.795
# episode  185 score -183.88 trailing 50 games avg -129.616
# episode  186 score -168.61 trailing 50 games avg -130.270
# episode  187 score -236.32 trailing 50 games avg -132.971
# episode  188 score -143.29 trailing 50 games avg -133.080
# episode  189 score -256.18 trailing 50 games avg -137.382
# episode  190 score -414.88 trailing 50 games avg -144.020
# episode  191 score -327.45 trailing 50 games avg -149.530
# episode  192 score -205.63 trailing 50 games avg -151.856
# episode  193 score 14.12 trailing 50 games avg -148.600
# episode  194 score -203.09 trailing 50 games avg -151.512
# episode  195 score -226.32 trailing 50 games avg -152.725
# episode  196 score -264.21 trailing 50 games avg -156.704
# episode  197 score -386.67 trailing 50 games avg -161.372
# episode  198 score -59.87 trailing 50 games avg -156.344
# episode  199 score 180.46 trailing 50 games avg -149.966
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  200 score -77.45 trailing 50 games avg -148.198
# episode  201 score -23.58 trailing 50 games avg -147.989
# episode  202 score -29.70 trailing 50 games avg -146.545
# episode  203 score -154.94 trailing 50 games avg -146.574
# episode  204 score -68.31 trailing 50 games avg -145.638
# episode  205 score -337.37 trailing 50 games avg -155.662
# episode  206 score -278.86 trailing 50 games avg -157.145
# episode  207 score -345.71 trailing 50 games avg -162.755
# episode  208 score -366.70 trailing 50 games avg -165.189
# episode  209 score -349.29 trailing 50 games avg -166.739
# episode  210 score -164.22 trailing 50 games avg -166.740
# episode  211 score -223.74 trailing 50 games avg -168.840
# episode  212 score -344.94 trailing 50 games avg -171.633
# episode  213 score -275.57 trailing 50 games avg -177.357
# episode  214 score -144.27 trailing 50 games avg -172.354
# episode  215 score -106.97 trailing 50 games avg -172.745
# episode  216 score -263.22 trailing 50 games avg -172.369
# episode  217 score -265.42 trailing 50 games avg -176.155
# episode  218 score -313.75 trailing 50 games avg -181.372
# episode  219 score -92.78 trailing 50 games avg -187.919
# episode  220 score -212.57 trailing 50 games avg -187.598
# episode  221 score -252.81 trailing 50 games avg -191.308
# episode  222 score -42.28 trailing 50 games avg -188.986
# episode  223 score -67.58 trailing 50 games avg -188.982
# episode  224 score -67.04 trailing 50 games avg -188.319
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  225 score -206.03 trailing 50 games avg -190.367
# episode  226 score -428.59 trailing 50 games avg -195.668
# episode  227 score -281.59 trailing 50 games avg -199.603
# episode  228 score -177.98 trailing 50 games avg -199.763
# episode  229 score -123.32 trailing 50 games avg -201.904
# episode  230 score -69.08 trailing 50 games avg -200.896
# episode  231 score -5.01 trailing 50 games avg -198.258
# episode  232 score -118.69 trailing 50 games avg -193.736
# episode  233 score -111.06 trailing 50 games avg -192.029
# episode  234 score -119.91 trailing 50 games avg -187.843
# episode  235 score -98.17 trailing 50 games avg -186.128
# episode  236 score -126.45 trailing 50 games avg -185.285
# episode  237 score -97.07 trailing 50 games avg -182.500
# episode  238 score -116.68 trailing 50 games avg -181.968
# episode  239 score 9.96 trailing 50 games avg -176.645
# episode  240 score -57.92 trailing 50 games avg -169.506
# episode  241 score -75.23 trailing 50 games avg -164.462
# episode  242 score -96.33 trailing 50 games avg -162.276
# episode  243 score -9.54 trailing 50 games avg -162.749
# episode  244 score -482.44 trailing 50 games avg -168.336
# episode  245 score -383.83 trailing 50 games avg -171.486
# episode  246 score -205.96 trailing 50 games avg -170.321
# episode  247 score -112.12 trailing 50 games avg -164.830
# episode  248 score -40.79 trailing 50 games avg -164.449
# episode  249 score -59.38 trailing 50 games avg -169.246
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  250 score -50.80 trailing 50 games avg -168.713
# episode  251 score -103.42 trailing 50 games avg -170.310
# episode  252 score -87.74 trailing 50 games avg -171.470
# episode  253 score -117.19 trailing 50 games avg -170.715
# episode  254 score -57.26 trailing 50 games avg -170.494
# episode  255 score -52.09 trailing 50 games avg -164.789
# episode  256 score -78.70 trailing 50 games avg -160.785
# episode  257 score -85.24 trailing 50 games avg -155.576
# episode  258 score -80.86 trailing 50 games avg -149.859
# episode  259 score -97.22 trailing 50 games avg -144.818
# episode  260 score -50.51 trailing 50 games avg -142.544
# episode  261 score -7.67 trailing 50 games avg -138.223
# episode  262 score -58.99 trailing 50 games avg -132.504
# episode  263 score -30.85 trailing 50 games avg -127.609
# episode  264 score -112.34 trailing 50 games avg -126.971
# episode  265 score -38.79 trailing 50 games avg -125.607
# episode  266 score -130.30 trailing 50 games avg -122.949
# episode  267 score -281.52 trailing 50 games avg -123.271
# episode  268 score -178.41 trailing 50 games avg -120.564
# episode  269 score 246.26 trailing 50 games avg -113.783
# episode  270 score -78.66 trailing 50 games avg -111.105
# episode  271 score -90.02 trailing 50 games avg -107.849
# episode  272 score -73.81 trailing 50 games avg -108.480
# episode  273 score 2.07 trailing 50 games avg -107.087
# episode  274 score 192.55 trailing 50 games avg -101.895
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode  275 score -0.39 trailing 50 games avg -97.782
# episode  276 score -51.76 trailing 50 games avg -90.245
# episode  277 score 209.52 trailing 50 games avg -80.423
# episode  278 score -232.08 trailing 50 games avg -81.505
# episode  279 score -233.83 trailing 50 games avg -83.715
# episode  280 score -295.68 trailing 50 games avg -88.247
# episode  281 score -31.46 trailing 50 games avg -88.776
# episode  282 score -116.68 trailing 50 games avg -88.736
# episode  283 score 255.98 trailing 50 games avg -81.395
# episode  284 score 209.73 trailing 50 games avg -74.803
# episode  285 score -10.12 trailing 50 games avg -73.042
# episode  286 score -63.77 trailing 50 games avg -71.788
# episode  287 score -8.94 trailing 50 games avg -70.026
# episode  288 score -93.62 trailing 50 games avg -69.564
# episode  289 score -61.78 trailing 50 games avg -70.999
# episode  290 score -66.51 trailing 50 games avg -71.171
# episode  291 score -168.98 trailing 50 games avg -73.046
# episode  292 score -22.18 trailing 50 games avg -71.563
# episode  293 score -12.35 trailing 50 games avg -71.619
# episode  294 score -68.42 trailing 50 games avg -63.339
# episode  295 score -75.75 trailing 50 games avg -57.177
# episode  296 score -19.56 trailing 50 games avg -53.449
# episode  297 score 14.11 trailing 50 games avg -50.925
# episode  298 score -27.58 trailing 50 games avg -50.660
# episode  299 score 222.77 trailing 50 games avg -45.017

# %%
# pickle.dump(agent, open(f'_DDPG_lunar_con_{len(score_history)}.p', "wb" ))
agent.save_models()
# Out:
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...
# ... saving checkpoint ...

# %%
#agent.load_models()

for i in range(3):
    obs = env.reset()
    done = False
    score = 0
    while not done:
        act = agent.choose_action(obs)
        new_state, reward, done, info = env.step(act)
        agent.remember(obs, act, reward, new_state, int(done))
        agent.learn()
        score += reward
        obs = new_state
        env.render()
    env.close()
    score_history.append(score)

    #if i % 25 == 0:
    #    agent.save_models()

    print('episode ', i, 'score %.2f' % score, 'trailing 50 games avg %.3f' % np.mean(score_history[-50:]))
# Out:
# episode  0 score 167.20 trailing 50 games avg 70.308
# episode  1 score 258.67 trailing 50 games avg 71.659
# episode  2 score -394.57 trailing 50 games avg 59.291
